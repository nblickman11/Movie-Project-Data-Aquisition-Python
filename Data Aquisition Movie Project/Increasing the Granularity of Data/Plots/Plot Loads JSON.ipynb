# %% [markdown]
# # DSCI 511: Data Acquisition and Pre-Processing - Final Project <br>

# %% [markdown]
# # 3. Increasing the Granularity of Data

# %% [markdown]
# <font size="4">**3.3. Plots**<font>

# %%
from bs4 import BeautifulSoup
import urllib 
import requests
import re
from collections import defaultdict
from collections import Counter
import json

# %% [markdown]
# Below is the output of `Counter` object after applying it over the dictionary of 100 movies, loaded from the previously-created JSON file.
#
# This dictionary records the number of words in each synopsis.

# %%
from collections import Counter

import json
file = open("plot_summary.json", "r").read()
summaries = json.loads(file)
#for key, value in summaries.items():
    #print(key)
    #print(value)
    #print()
    #print("Next Movie:")  

    
    
# Creating Word Counts for the Synopsis of every movie.     
final = {}
i = 1
for key, values in summaries.items():
    lst = values.split(" ")
    movie_count = Counter()
    for item in lst:
        movie_count[item] += 1
    final.update({str(i):movie_count})
    i+=1

for key, values in final.items():
    print(key)
    print(values)
    print()
    print("Next Movie:")
# Out:
# 1
# Counter({'the': 5, 'Synopsis': 2, '\nIt': 1, 'looks': 1, 'like': 1, 'we': 1, "don't": 1, 'have': 1, 'a': 1, 'for': 1, 'this': 1, 'title': 1, 'yet.': 1, 'Be': 1, 'first': 1, 'to': 1, 'contribute!': 1, 'Just': 1, 'click': 1, '"Edit': 1, 'page"': 1, 'button': 1, 'at': 1, 'bottom': 1, 'of': 1, 'page': 1, 'or': 1, 'learn': 1, 'more': 1, 'in': 1, 'submission': 1, 'guide.\n': 1})
#
# Next Movie:
# 2
# ...
